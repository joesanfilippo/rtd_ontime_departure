# %%
from google.transit import gtfs_realtime_pb2
import requests
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import numpy as np
import geopy.distance as geo

# %% [markdown]
# # Functions

# %%
def pull_vehicle_data():
    # Pull feed from RTD-Denver's VehiclePosition URL
    feed = gtfs_realtime_pb2.FeedMessage()
    response = requests.get('https://www.rtd-denver.com/files/gtfs-rt/VehiclePosition.pb')
    feed.ParseFromString(response.content)
    return feed

# %%
def parse_to_df(feed):
    # Store the necessary values in a dictionary to convert to a Pandas Dataframe for later analysis
    rtd_dict = {}

    for entity in feed.entity:
        rtd_dict[entity.id] = {'trip_id': entity.vehicle.trip.trip_id
                            ,'route_id': entity.vehicle.trip.route_id
                            ,'vehicle_lat': float(entity.vehicle.position.latitude)
                            ,'vehicle_lng': float(entity.vehicle.position.longitude)
                            ,'bearing': int(entity.vehicle.position.bearing)
                            ,'status': int(entity.vehicle.current_status)
                            ,'timestamp': int(entity.vehicle.timestamp)
                            ,'stop_id': entity.vehicle.stop_id
                            ,'vehicle_id': entity.vehicle.vehicle.id
                            ,'vehicle_label': entity.vehicle.vehicle.label}

    return pd.DataFrame.from_dict(rtd_dict, orient='index').reset_index()

# %%
def clean_up_nulls(rtd_column, new_value):
    rtd_column = rtd_column.replace('', new_value)
        
    if type(new_value) == int: 
        rtd_column = rtd_column.astype('int')

    return rtd_column

# %%
def update_col_names(rtd_cols):
    # Update the first column name to be entity_id, a unique value for the pull (combination of 'timestamp + _ + vehicle_id')
    col_list = rtd_cols.tolist()
    col_list[0] = 'entity_id'
    return col_list

# %%
def convert_timezone_local(rtd_timestamps): 
    # Convert the timestamp values to Mountain Time from UTC
    return pd.to_datetime(rtd_timestamps, unit='s').dt.tz_localize('UTC').dt.tz_convert('US/Mountain')

# %%
def convert_vals(rtd_column, val_dict):
    # Update status columns with their corresponding real_world values
    return rtd_column.replace(to_replace = val_dict)

# %%
def put_it_all_together(rtd_df, routes, trips, stops, stop_times):
    rtd_df = pd.merge(rtd_df, routes, how='left', on=['route_id'], suffixes=('', '_r'))
    rtd_df = pd.merge(rtd_df, trips, how='left', on=['trip_id'], suffixes=('', '_t'))
    rtd_df = pd.merge(rtd_df, stops, how='left', on=['stop_id'], suffixes=('', '_s'))
    rtd_df = pd.merge(rtd_df, stop_times, how='left', on=['trip_id', 'stop_id'], suffixes=('', '_st'))
    return rtd_df.loc[:,['entity_id'
                  ,'trip_id'
                  ,'trip_headsign'
                  ,'route_id'
                  ,'route_long_name'
                  ,'route_short_name'
                  ,'route_type'
                  ,'route_desc'
                  ,'vehicle_lat'
                  ,'vehicle_lng'
                  ,'bearing'
                  ,'status'
                  ,'timestamp'
                  ,'stop_id'
                  ,'stop_name'
                  ,'stop_desc'
                  ,'stop_lat'
                  ,'stop_lon'
                  ,'arrival_time'
                  ,'departure_time'
                  ,'vehicle_id'
                  ,'vehicle_label']]

# %%
def initialize_csv(filepath, col_length, col_names):
    # Initialize the CSV to store the data (Remove for subsequent runs)
    init_csv = pd.DataFrame([['']*col_length], columns = col_names.tolist()).reset_index(drop=True)
    init_csv.to_csv(filepath, index=False)

# %%
def append_csv(filepath, rtd_df, update_datetime):
    # Append the data onto the end of the CSV
    try:
        rtd_df.to_csv(filepath, mode='a', header=False, index=False)
        print(f"Feed Updated at: {update_datetime}")
    except:
        print('Somthing went wrong...')

# %%
def calculate_distance(point_1_lat, point_1_lng, point_2_lat, point_2_lng):
    # Calculate the distance between two geo points in meters
    point_1 = list(zip(point_1_lat, point_1_lng))
    point_2 = list(zip(point_2_lat, point_2_lng))
    
    return [round(geo.distance(point_1, point_2).m,2) if (~pd.isnull(point_2[0])) & (point_1[0] > 0) else np.nan for point_1, point_2 in zip(point_1, point_2)]

# %%
def calculate_time(time_1, time_2):
    # Calculate the time between a Timestamp and an H:M:S string in minutes
    time_diff = time_1.dt.tz_localize(None) - time_2.apply(lambda x: pd.Timestamp(x))
    return time_diff.apply(lambda x: x.total_seconds()/60)

# %%
type(calculate_time(rtd_df.timestamp, rtd_df.scheduled_arrival_time)[0])
# Out:
# numpy.float64

# %% [markdown]
# # Pull Scripts

# %%
status_dict = {0: 'incoming_at'
              ,1: 'stopped_at'
              ,2: 'in_transit_to'}

route_dict = {0: 'light_rail'
             ,2: 'union_station_rail'
             ,3: 'bus'}

# %%
rtd_pull = pull_vehicle_data()
rtd_df = parse_to_df(rtd_pull)

rtd_df.trip_id = clean_up_nulls(rtd_df.trip_id, -1)
rtd_df.stop_id = clean_up_nulls(rtd_df.stop_id, -1)
rtd_df.route_id = clean_up_nulls(rtd_df.route_id, np.nan)
rtd_df.columns = update_col_names(rtd_df.columns)

rtd_df.head()
# Out:
#          entity_id    trip_id route_id  vehicle_lat  vehicle_lng  bearing  \
# 0  1613088221_1505         -1      NaN    39.616585  -104.897766      156
# 1  1613088221_1516  113624099      AB1    39.974968  -105.209198      300
# 2  1613088221_1535  113611060     104L    39.884766  -104.942902       91
# 3  1613088221_1543  113611074     104L    39.885700  -104.781754      270
# 4  1613088221_1549         -1      NaN    39.771233  -104.984314        0
#
#    status   timestamp  stop_id vehicle_id vehicle_label
# 0       2  1613088189       -1       1505          1505
# 1       2  1613088188    33855       1516          1516
# 2       2  1613088205    23499       1535          1535
# 3       2  1613088167    33278       1543          1543
# 4       2  1613088215       -1       1549          1549

# %%
routes = pd.read_csv('~/Documents/dsi/repos/capstone_1/data/google_transit/routes.txt', delimiter=',')
trips = pd.read_csv('~/Documents/dsi/repos/capstone_1/data/google_transit/trips.txt', delimiter=',')
stops = pd.read_csv('~/Documents/dsi/repos/capstone_1/data/google_transit/stops.txt', delimiter=',')
stop_times = pd.read_csv('~/Documents/dsi/repos/capstone_1/data/google_transit/stop_times.txt', delimiter=',')

# %%
stop_times[stop_times.trip_id == '113627040']
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# Empty DataFrame
# Columns: [trip_id, arrival_time, departure_time, stop_id, stop_sequence, stop_headsign, pickup_type, drop_off_type, shape_dist_traveled, timepoint]
# Index: []

# %%
rtd_df = put_it_all_together(rtd_df, routes, trips, stops, stop_times)
rtd_df.timestamp = convert_timezone_local(rtd_df.timestamp)
rtd_df.status = convert_vals(rtd_df.status, status_dict)
rtd_df.route_type = convert_vals(rtd_df.route_type, route_dict)
col_names = rtd_df.columns.tolist()
col_names[col_names.index('arrival_time')] = 'scheduled_arrival_time'
col_names[col_names.index('departure_time')] = 'scheduled_departure_time'
rtd_df.columns = col_names

# %%
rtd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 415 entries, 0 to 414
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   entity_id                 415 non-null    object
#  1   trip_id                   415 non-null    int64
#  2   trip_headsign             324 non-null    object
#  3   route_id                  324 non-null    object
#  4   route_long_name           324 non-null    object
#  5   route_short_name          324 non-null    object
#  6   route_type                324 non-null    object
#  7   route_desc                324 non-null    object
#  8   vehicle_lat               415 non-null    float64
#  9   vehicle_lng               415 non-null    float64
#  10  bearing                   415 non-null    int64
#  11  status                    415 non-null    object
#  12  timestamp                 415 non-null    datetime64[ns, US/Mountain]
#  13  stop_id                   415 non-null    int64
#  14  stop_name                 322 non-null    object
#  15  stop_desc                 322 non-null    object
#  16  stop_lat                  322 non-null    float64
#  17  stop_lon                  322 non-null    float64
#  18  scheduled_arrival_time    318 non-null    object
#  19  scheduled_departure_time  318 non-null    object
#  20  vehicle_id                415 non-null    object
#  21  vehicle_label             415 non-null    object
# dtypes: datetime64[ns, US/Mountain](1), float64(4), int64(3), object(14)
# memory usage: 74.6+ KB

# %%
rtd_df.head()
# Out:
#          entity_id    trip_id                                   trip_headsign  \
# 0  1613088221_1505         -1                                             NaN
# 1  1613088221_1516  113624099                      Downtown Boulder via E-470
# 2  1613088221_1535  113611060  Denver Airport Station via Thornton Crossroads
# 3  1613088221_1543  113611074          Wagon Road PnR via Thornton Crossroads
# 4  1613088221_1549         -1                                             NaN
#
#   route_id                      route_long_name route_short_name route_type  \
# 0      NaN                                  NaN              NaN        NaN
# 1      AB1             Boulder / Denver Airport              AB1        bus
# 2     104L  Wagon Road / Denver Airport Limited             104L        bus
# 3     104L  Wagon Road / Denver Airport Limited             104L        bus
# 4      NaN                                  NaN              NaN        NaN
#
#                                  route_desc  vehicle_lat  vehicle_lng  \
# 0                                       NaN    39.616585  -104.897766
# 1  This Route Travels Eastbound & Westbound    39.974968  -105.209198
# 2  This Route Travels Eastbound & Westbound    39.884766  -104.942902
# 3  This Route Travels Eastbound & Westbound    39.885700  -104.781754
# 4                                       NaN    39.771233  -104.984314
#
#    bearing         status                 timestamp  stop_id  \
# 0      156  in_transit_to 2021-02-11 17:03:09-07:00       -1
# 1      300  in_transit_to 2021-02-11 17:03:08-07:00    33855
# 2       91  in_transit_to 2021-02-11 17:03:25-07:00    23499
# 3      270  in_transit_to 2021-02-11 17:02:47-07:00    33278
# 4        0  in_transit_to 2021-02-11 17:03:35-07:00       -1
#
#                            stop_name                      stop_desc  \
# 0                                NaN                            NaN
# 1  US 36 & Table Mesa Station Gate B       Vehicles Travelling East
# 2                                NaN                            NaN
# 3            104th Ave & Landmark Dr  Vehicles Travelling Southwest
# 4                                NaN                            NaN
#
#     stop_lat    stop_lon scheduled_arrival_time scheduled_departure_time  \
# 0        NaN         NaN                    NaN                      NaN
# 1  39.986706 -105.232717               17:16:00                 17:16:00
# 2        NaN         NaN                    NaN                      NaN
# 3  39.885712 -104.791061               17:02:56                 17:02:56
# 4        NaN         NaN                    NaN                      NaN
#
#   vehicle_id vehicle_label
# 0       1505          1505
# 1       1516          1516
# 2       1535          1535
# 3       1543          1543
# 4       1549          1549

# %% [markdown]
# # Routes, Trips, Stops, & Stop Times

# %%
routes = pd.read_csv('~/Documents/dsi/repos/capstone_1/data/google_transit/routes.txt', delimiter=',')
routes.route_desc.unique()
# Out:
# array(['This Route Travels Eastbound & Westbound',
#        'This Route Travels Northbound & Southbound',
#        'This Route Travels Civic Ctr & Union Stn'], dtype=object)

# %%
routes[routes.route_type == 2]
# Out:
#                               route_long_name  route_type route_text_color  \
# 31       Union Station to Westminster Station           2           FFFFFF
# 32  Union Station to Wheat Ridge Ward Station           2           FFFFFF
# 91  Union Station to Eastlake & 124th Station           2           FFFFFF
# 92    Union Station to Denver Airport Station           2           FFFFFF
#
#    route_color agency_id route_id                                  route_url  \
# 31      4E9D2D       RTD     113B  http://www.rtd-denver.com/Schedules.shtml
# 32      F6B221       RTD     113G  http://www.rtd-denver.com/Schedules.shtml
# 91      9F26B5       RTD     117N  http://www.rtd-denver.com/Schedules.shtml
# 92      57C1E9       RTD        A  http://www.rtd-denver.com/Schedules.shtml
#
#                                     route_desc route_short_name
# 31    This Route Travels Eastbound & Westbound                B
# 32    This Route Travels Eastbound & Westbound                G
# 91  This Route Travels Northbound & Southbound                N
# 92    This Route Travels Eastbound & Westbound                A

# %%
trips = pd.read_csv('~/Documents/dsi/repos/capstone_1/data/google_transit/trips.txt', delimiter=',')
trips.head()
# Out:
#   block_id route_id  direction_id                 trip_headsign  shape_id  \
# 0  a_51  3       51             0               US36 & Sheridan   1169566
# 1  b_76  5       76             1              Lakewood Commons   1178320
# 2  b_FF  5      FF1             1  Downtown Boulder All-Station   1178609
# 3  b_FF  4      FF3             1             US36 & Broomfield   1178617
# 4  b_FF  2      FF1             1  Downtown Boulder All-Station   1178616
#
#             service_id    trip_id
# 0  WK_merged_113737461  113621307
# 1  SU_merged_113737468  113732618
# 2  SU_merged_113737468  113735135
# 3  SU_merged_113737468  113735134
# 4  SU_merged_113737468  113735137

# %%
stops = pd.read_csv('~/Documents/dsi/repos/capstone_1/data/google_transit/stops.txt', delimiter=',')
stops.head()
# Out:
#     stop_lat  wheelchair_boarding  stop_code    stop_lon  stop_timezone  \
# 0  39.781251                    1      35236 -105.138657            NaN
# 1  39.767591                    1      35234 -104.973545            NaN
# 2  39.764239                    1      35232 -104.977870            NaN
# 3  39.765885                    1      35233 -104.975756            NaN
# 4  39.760294                    1      35230 -104.982985            NaN
#
#    stop_url  parent_station                  stop_desc  \
# 0       NaN         33852.0  Vehicles Travelling South
# 1       NaN             NaN   Vehicles Travelling East
# 2       NaN             NaN   Vehicles Travelling East
# 3       NaN             NaN   Vehicles Travelling East
# 4       NaN             NaN   Vehicles Travelling East
#
#                  stop_name  location_type  stop_id zone_id
# 0         Ward Rd PnR (Ar)              0    35236   35236
# 1  Larimer St & Downing St              0    35234   35234
# 2     Larimer St & 32nd St              0    35232   35232
# 3     Larimer St & 34th St              0    35233   35233
# 4     Larimer St & 28th St              0    35230   35230

# %%
stop_times = pd.read_csv('~/Documents/dsi/repos/capstone_1/data/google_transit/stop_times.txt', delimiter=',')
stop_times.head()
# Out:
#      trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 0  113621307     08:03:00       08:03:00    26180              1
# 1  113621307     08:04:43       08:04:43    20171              2
# 2  113621307     08:06:14       08:06:14    35227              3
# 3  113621307     08:07:54       08:07:54    20312              4
# 4  113621307     08:08:55       08:08:55    20314              5
#
#    stop_headsign  pickup_type  drop_off_type  shape_dist_traveled  timepoint
# 0            NaN          NaN            1.0                  NaN        NaN
# 1            NaN          NaN            NaN                  NaN        NaN
# 2            NaN          NaN            NaN                  NaN        NaN
# 3            NaN          NaN            NaN                  NaN        NaN
# 4            NaN          NaN            NaN                  NaN        NaN

# %% [markdown]
# # Calculating Meters between 2 points

# %%
# point_1 = (float(AB_route[(AB_route.entity_id == '1612967622_1510')].vehicle_lat), float(AB_route[(AB_route.entity_id == '1612967622_1510')].vehicle_lng))
# point_2 = (float(AB_route[(AB_route.entity_id == '1612967743_1510')].vehicle_lat), float(AB_route[(AB_route.entity_id == '1612967743_1510')].vehicle_lng))
geom_df = rtd_df[~(rtd_df.vehicle_lat.isnull()) & ~(rtd_df.stop_lat.isnull())]
geom_df['vehicle_point'] = list(zip(geom_df.loc[:,'vehicle_lat'], geom_df.loc[:,'vehicle_lng']))
geom_df['stop_point'] = list(zip(geom_df.loc[:,'stop_lat'], geom_df.loc[:,'stop_lon']))

geom_df['distance_to_stop_meters'] = geom_df.apply(lambda row: geo.distance(row['vehicle_point'], row['stop_point']).m, axis=1).round(1)
geom_df
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#                                        entity_id    trip_id  \
# 0                                1613015131_1502  113611084
# 1                                1613015131_1516  113611064
# 4                                1613015131_1529  113624239
# 10                               1613015131_1653  113630356
# 14                               1613015131_1679  113630437
# 15                               1613015131_1681  113630357
# 18                               1613015131_3605  113632634
# 19                               1613015131_3609  113624983
# 22                               1613015131_3615  113624981
# 23                               1613015131_3618  113624085
# 24                               1613015131_3629  113624982
# 34                               1613015131_3702  113624084
# 35                               1613015131_3703  113624104
# 36                               1613015131_3705  113632608
# 38                               1613015131_3712  113625025
# 43                               1613015131_3941  113619830
# 49                               1613015131_5081  113616799
# 50                               1613015131_5109  113622460
# 53                               1613015131_5121  113633887
# 54                               1613015131_5122  113634435
# 55                               1613015131_5123  113634442
# 56                               1613015131_5126  113622293
# 57                               1613015131_5127  113618988
# 58                               1613015131_5132  113634057
# 61                               1613015131_5139  113611353
# 64                               1613015131_5149  113623053
# 65                               1613015131_5152  113619327
# 71                               1613015131_5166  113623219
# 72                               1613015131_5167  113623259
# 73                               1613015131_5168  113619706
# 74                               1613015131_5170  113616631
# 75                               1613015131_5171  113608110
# 79                               1613015131_5182  113613581
# 80                               1613015131_5183  113620549
# 81                               1613015131_5185  113616608
# 82                               1613015131_5186  113616768
# 83                               1613015131_5187  113608101
# 85                               1613015131_5197  113625292
# 86                               1613015131_5199  113617522
# 87                               1613015131_5203  113617400
# 89                               1613015131_5207  113624545
# 91                               1613015131_5212  113616891
# 93                               1613015131_5217  113625361
# 94                               1613015131_5219  113625314
# 95                               1613015131_5227  113617444
# 97                               1613015131_5247  113619295
# 98                               1613015131_5248  113619346
# 100                              1613015131_5251  113618018
# 101                              1613015131_5254  113618017
# 103                              1613015131_5257  113621360
# 105                              1613015131_5263  113615185
# 106                              1613015131_6001  113615532
# 19                           Union Station All-Station      FF1
# 22                           Union Station All-Station      FF1
# 23                            Denver Airport via E-470      AB1
# 24                           Union Station All-Station      FF1
# 34                            Denver Airport via E-470      AB1
# 35                          Downtown Boulder via E-470      AB1
# 36                                         8th/Coffman     BOLT
# 38                        Downtown Boulder All-Station      FF1
# 43                                         Mineral Stn     402L
# 49                                       Union Station       20
# 50                                         US36 & Bfld       76
# 53                                        106th&Melody       31
# 54                                 Westminster Station       31
# 55                                               Evans       31
# 56                            Belleview Stn via Quebec       73
# 57                                           Evans Ave       35
# 58                                               Evans       31
# 61                                        Central Park      105
# 64       Original Thornton & 88th Ave Stn via 88th Ave      88L
# 65                          Ward Rd & I-70 Park-n-Ride       38
# 71   Original Thornton & 88th Ave Stn via Thornton PnR       92
# 72                                      Wadsworth/88th       92
# 73                         Southmoor via Colorado Blvd       40
# 74                                Civic Center Station       19
# 75                           9th Clermont via 12th Ave       10
# 79              Eastlake & 124th Ave Stn via 120th Ave     120E
# 80                          Ward Rd & I-70 Park-n-Ride       44
# 81                                      106th & Melody       19
# 82                             Anschutz Medical Campus       20
# 83                           9th Clermont via 12th Ave       10
# 85                               Erie Community Center     JUMP
# 86                                        Hecla/Kaylix      228
# 87                                       Lafayette PnR      225
# 89                              Broadway 27th via 30th     BOND
# 91                            Downtown Boulder Station      204
# 93                                 US36/Broomfield Stn      LD3
# 94                                        Dwtn Boulder     JUMP
# 95                                        Dtwn Boulder      225
# 97                                            Downtown       38
# 98                          Ward Rd & I-70 Park-n-Ride       38
# 100                                     Federal Center        3
# 101                                   Lakewood Commons        3
# 103                                      Englewood Stn       51
# 105                                           Tower Rd       15
# 106                                   Arapahoe Station      153
# 108                  Englewood Stn via Corona & Colfax       12
# 109                                           Broadway       16
# 112                                        Oak Station       16
# 115                                   26th & Wadsworth       32
# 117                                           Broadway       16
# 123                             Union Station Downtown       15
# 124                         Central Park 73 via Quebec       73
# 126                            Ulster Tufts via Havana      105
# 127                      Aurora Metro Cntr via Buckley      130
# 128                     Central Park Stn via Montbello       42
# 130                            Peoria Stn via Chambers      153
# 131                           Peoria Stn via Montbello       45
# 133                   40th & Airport Stn via Montbello      121
# 134                  Aurora Metro Cntr via Mississippi       11
# 135                  40th & Airport Stn via Buckley Rd      169
# 136                                 Green Valley Ranch       42
# 137                                 Green Valley Ranch       45
# 138                               Nine Mile via Peoria      121
# 139                               Nine Mile via Peoria      121
# 140                                   Arapahoe Station      153
# 141                             Union Station Downtown       15
# 142                   40th & Airport Stn via Montbello      121
# 143                      Aurora Metro Cntr via Buckley      130
# 144                            Peoria Stn via Chambers      153
# 145                                       Central Park      105
# 146                  Englewood Stn via Corona & Colfax       12
# 148                                   Auraria Downtown       43
# 150                           Belleview Stn via Quebec       73
# 154                                       106th&Melody       31
# 155                         Central Park 73 via Quebec       73
# 157                                     Federal Center        3
# 160                                         Lincoln St        3
# 161                     Lakewood Commons via Mosier Pl       11
# 163                                        Long/Bowles       76
# 164                                      Union Station       32
# 166                          Aurora Metro Cntr via 6th        6
# 167                        Southmoor via Colorado Blvd       40
# 168        120L Eastlake & 124th Ave Stn via 120th Ave     120L
# 169                                      Union Station       10
# 171                                    Auraria via 6th        6
# 173                                       Dtwn Boulder     DASH
# 174                               Front Range/Broadway     SKIP
# 175                                          Littleton       36
# 176                           Fairview HS via Broadway     SKIP
# 177                                      Lafayette PnR     DASH
# 178                               Front Range/Broadway     SKIP
# 179                                        Oak Station       16
# 181                        Aurora Metro Cntr via Evans       21
# 182                  Englewood Stn via Corona & Colfax       12
# 185                          Nine Mile Stn via Buckley      130
# 186                           Fairview HS via Broadway     SKIP
# 187                            Central Park via Monaco       65
# 188                             Union Station Downtown       15
# 189                          Billings via E Colfax Ave       15
# 190                            Ulster Tufts via Havana      105
# 193                             Union Station Downtown       15
# 194                     Central Park Stn via Montbello       42
# 200                               Nine Mile via Peoria      121
# 201                        Aurora Metro Cntr via Tower      133
# 202                                           Tower Rd       15
# 203                                           Broadway       16
# 204    Northglenn & 112th Ave Stn via Downing & Colfax       12
# 205                           Peoria Stn via Montbello       45
# 207                            Nine Mile Stn via Tower      133
# 208                          Southlands via Smoky Hill      135
# 209                             Union Station Downtown       15
# 213    Northglenn & 112th Ave Stn via Downing & Colfax       12
# 214                          Central Park via MLK Blvd       43
# 217                                              Evans       36
# 223           120L US 85 & Bridge St PnR via 120th Ave     120L
# 225                    Commerce City via Colorado Blvd       40
# 226                                             Golden       16
# 227                                           Broadway       16
# 228                                            Kipling       21
# 230                                   Lakewood Commons        1
# 233                                Westminster Station       31
# 237                                    US36 & Sheridan       51
# 238                                   Coal Mine/Bowles       59
# 240                                       Arapahoe Stn       66
# 242                                        Long/Bowles       76
# 243                Central Park Stn via Bruce Randolph       34
# 244                     Lakewood Commons via Mosier Pl       11
# 246                      Aurora Metro Cntr via Alameda        3
# 248                                      Englewood Stn       51
# 249                                  Park Meadows Mall     402L
# 250                                Westminster Station       31
# 251                                              Evans       31
# 267                         Ward & 64th via W 50th Ave       52
# 268                                        Alameda Stn       52
# 270                          Billings via E Colfax Ave      15L
# 272                                          Nine Mile      83L
# 273                        Aurora Metro Center Station      15L
# 274                       Decatur Station via E Colfax      15L
# 275                                      Union Station        0
# 277                                      Union Station        0
# 278                                      Union Station        0
# 279                                      Union Station        0
# 283                                       Broadway Stn        0
# 284    Northglenn & 112th Ave Stn via Downing & Colfax       12
# 286                                      Union Station        0
# 287                                    Highlands Ranch        0
# 289                              Downtown Civic Center      83L
# 290                       Decatur Station via E Colfax      15L
# 291                                          Nine Mile      83L
# 292                       Decatur Station via E Colfax      15L
# 293                                    Highlands Ranch        0
# 295                        Aurora Metro Center Station      15L
# 296                           D-Line 18th & California     101D
# 297                                   E-Line RidgeGate     101E
# 298                                      W-Line Jeffco     103W
# 299                           H-Line 18th & California     101H
# 300                                     H-Line Florida     101H
# 301                           D-Line 18th & California     101D
# 302                                 W-Line Federal Ctr     103W
# 303                               E-Line Union Station     101E
# 304                                   E-Line RidgeGate     101E
# 305                               W-Line Union Station     103W
# 306                               W-Line Union Station     103W
# 290                                East Colfax Limited              15L
# 291                   Cherry Creek / Parker Rd Limited              83L
# 292                                East Colfax Limited              15L
# 293                                     South Broadway                0
# 295                                East Colfax Limited              15L
# 296  18th & California Station to Littleton-Mineral...                D
# 297         Union Station to RidgeGate Parkway Station                E
# 298  Union Station to Jefferson County Government C...                W
# 299       18th & California Station to Florida Station                H
# 300       18th & California Station to Florida Station                H
# 301  18th & California Station to Littleton-Mineral...                D
# 302  Union Station to Jefferson County Government C...                W
# 303         Union Station to RidgeGate Parkway Station                E
# 304         Union Station to RidgeGate Parkway Station                E
# 305  Union Station to Jefferson County Government C...                W
# 306  Union Station to Jefferson County Government C...                W
# 307       18th & California Station to Florida Station                H
# 308  18th & California Station to Littleton-Mineral...                D
# 309         Union Station to RidgeGate Parkway Station                E
# 310  18th & California Station to Littleton-Mineral...                D
# 311  18th & California Station to Littleton-Mineral...                D
# 312         Union Station to RidgeGate Parkway Station                E
# 313       18th & California Station to Florida Station                H
# 314         Union Station to RidgeGate Parkway Station                E
# 315       18th & California Station to Florida Station                H
# 316         Union Station to RidgeGate Parkway Station                E
# 317         Union Station to RidgeGate Parkway Station                E
# 318       18th & California Station to Florida Station                H
# 319  Union Station to Jefferson County Government C...                W
# 320       18th & California Station to Florida Station                H
# 321  Union Station to Jefferson County Government C...                W
# 322  18th & California Station to Littleton-Mineral...                D
# 323                     30th & Downing to 16th & Stout                L
#
#      route_type                                  route_desc  vehicle_lat  \
# 0           bus    This Route Travels Eastbound & Westbound    39.848083
# 1           bus    This Route Travels Eastbound & Westbound    39.885216
# 4           bus  This Route Travels Northbound & Southbound    39.625648
# 10          bus    This Route Travels Civic Ctr & Union Stn    39.746582
# 14          bus    This Route Travels Civic Ctr & Union Stn    39.751183
# 15          bus    This Route Travels Civic Ctr & Union Stn    39.754768
# 18          bus  This Route Travels Northbound & Southbound    40.101215
# 19          bus    This Route Travels Eastbound & Westbound    39.769684
# 22          bus    This Route Travels Eastbound & Westbound    40.017384
# 23          bus    This Route Travels Eastbound & Westbound    39.985767
# 24          bus    This Route Travels Eastbound & Westbound    39.979851
# 34          bus    This Route Travels Eastbound & Westbound    39.846966
# 35          bus    This Route Travels Eastbound & Westbound    39.984531
# 36          bus  This Route Travels Northbound & Southbound    40.017868
# 38          bus    This Route Travels Eastbound & Westbound    39.904251
# 43          bus    This Route Travels Eastbound & Westbound    39.559132
# 49          bus    This Route Travels Eastbound & Westbound    39.746201
# 50          bus  This Route Travels Northbound & Southbound    39.719467
# 53          bus  This Route Travels Northbound & Southbound    39.888668
# 54          bus  This Route Travels Northbound & Southbound    39.737717
# 55          bus  This Route Travels Northbound & Southbound    39.750217
# 56          bus  This Route Travels Northbound & Southbound    39.706451
# 57          bus    This Route Travels Eastbound & Westbound    39.667717
# 58          bus  This Route Travels Northbound & Southbound    39.699600
# 61          bus  This Route Travels Northbound & Southbound    39.769817
# 64          bus  This Route Travels Northbound & Southbound    39.841801
# 65          bus    This Route Travels Eastbound & Westbound    39.769382
# 319                   (39.736683, -105.066872)                   1098.3
# 320           (39.746121, -104.99283799999999)                    208.1
# 321                    (39.720037, -105.12964)                    186.8
# 322           (39.677331, -104.99294599999999)                    541.2
# 323           (39.753528, -104.97949299999999)                     89.6

# %% [markdown]
# # Calculating time between two times

# %%
rtd_df.timestamp[0].tz_localize(None)
# Out:
# Timestamp('2021-02-10 20:45:10')

# %%
pd.Timestamp(rtd_df.scheduled_arrival_time[0])
# Out:
# Timestamp('2021-02-10 20:50:00')

# %%
(rtd_df.timestamp[0].tz_localize(None) - pd.Timestamp(rtd_df.scheduled_arrival_time[0])).total_seconds()//60
# Out:
# -5.0

# %%
time_df = rtd_df[~(rtd_df.timestamp.isnull()) & ~(rtd_df.scheduled_arrival_time.isnull())]

# %%
time_diff = time_df['timestamp'].dt.tz_localize(None) - time_df['scheduled_arrival_time'].apply(lambda x: pd.Timestamp(x))
time_diff.apply(lambda x: x.total_seconds()/60)
# Out:
# 0      -4.833333
# 1      -1.983333
# 4      -7.166667
# 10      1.516667
# 14     -0.716667
# 15      0.533333
# 18      5.916667
# 19     -4.183333
# 22    -16.100000
# 23     -1.200000
# 24     -3.916667
# 34     -1.950000
# 35     -6.083333
# 36      2.183333
# 38     -1.150000
# 43      4.583333
# 49      1.100000
# 50      3.550000
# 53      1.266667
# 54      1.150000
# 55     -0.883333
# 56     -1.683333
# 57     -0.116667
# 58     -1.250000
# 61     -0.183333
# 64      4.000000
# 65      0.350000
# 71      2.900000
# 72     -0.133333
# 73      2.283333
# 74      2.283333
# 75      1.166667
# 79      3.350000
# 80      6.066667
# 81      1.250000
# 82      0.883333
# 83      1.316667
# 85      1.600000
# 86      4.066667
# 87      3.000000
# 89      0.283333
# 91      1.616667
# 93     -1.283333
# 94      0.566667
# 95      3.000000
# 97      0.766667
# 98      2.600000
# 100     2.466667
# 101     1.616667
# 103    -1.516667
# 105     0.933333
# 106     0.133333
# 108    -6.033333
# 112    -0.283333
# 115     1.800000
# 117     3.066667
# 124    -0.016667
# 126    -5.816667
# 127     3.133333
# 128    -3.266667
# 130     1.200000
# 131     1.333333
# 133     1.283333
# 134     0.466667
# 135    -0.866667
# 136    -2.850000
# 137     0.600000
# 138     0.383333
# 139    -1.200000
# 140     0.183333
# 141     2.266667
# 142    -4.066667
# 144     0.666667
# 145     1.850000
# 146    -2.733333
# 148     3.283333
# 150     0.183333
# 154    -0.250000
# 155    -0.250000
# 157    12.983333
# 160     1.200000
# 161     2.166667
# 163    -0.266667
# 164    -0.200000
# 166     7.083333
# 167     2.750000
# 168     1.133333
# 169    -0.816667
# 171     1.116667
# 173    -0.116667
# 174    -3.466667
# 175    -2.166667
# 176    -1.900000
# 177     1.350000
# 178    -0.483333
# 179     1.716667
# 181    -2.166667
# 182     5.966667
# 185     0.400000
# 186     3.783333
# 187     3.800000
# 188    -1.183333
# 189     0.350000
# 190    -1.483333
# 193     0.816667
# 194    -0.516667
# 200     0.133333
# 201     0.433333
# 202     0.850000
# 204     2.583333
# 205     3.050000
# 207     2.050000
# 208     0.433333
# 213     0.666667
# 214    -1.283333
# 217    -1.866667
# 223     1.650000
# 225     0.383333
# 226    -2.583333
# 227    -0.250000
# 228    -1.433333
# 230     3.950000
# 233    -0.216667
# 237     0.050000
# 238     1.516667
# 240    -1.083333
# 242     0.000000
# 243     2.233333
# 244    -0.366667
# 246     4.933333
# 248    -0.800000
# 249     2.283333
# 250     1.283333
# 251     0.000000
# 267     1.733333
# 268     0.650000
# 270    -2.050000
# 272    -1.250000
# 273    -0.850000
# 274     3.016667
# 275     3.300000
# 278     1.800000
# 279     0.850000
# 283     0.200000
# 284     8.316667
# 286    -4.266667
# 287    -0.433333
# 289    -1.216667
# 290    11.883333
# 291    -1.500000
# 292     1.800000
# 293     1.283333
# 295    -0.816667
# 296     0.316667
# 297     2.450000
# 298     0.516667
# 299    -2.233333
# 300     0.050000
# 301    -1.066667
# 302    -2.266667
# 303    -0.616667
# 304    -2.533333
# 305     1.616667
# 306     1.266667
# 307     5.933333
# 308     2.366667
# 309    -1.800000
# 310     3.150000
# 311    -0.633333
# 312    -2.950000
# 313    -1.316667
# 314   -16.200000
# 315    -1.400000
# 316    -1.533333
# 317    -1.283333
# 318    -2.966667
# 319    -2.150000
# 320    -0.650000
# 321    -0.816667
# 322    -0.800000
# 323     2.533333
# dtype: float64

# %% [markdown]
# # Calculating null values by vehicle ID

# %%
rtd_csv.stop_name.isnull().groupby(rtd_csv.vehicle_id).sum().astype(int).reset_index(name='count_nulls').sort_values('count_nulls', ascending=False)
# Out:
# Empty DataFrame
# Columns: [vehicle_id, count_nulls]
# Index: []

# %%
rtd_df.head()
# Out:
#          entity_id    trip_id                           trip_headsign  \
# 0  1613069281_1504  113624249                            Arapahoe Stn
# 1  1613069281_1505  113624215                          Denver Airport
# 2  1613069281_1509  113624080                Denver Airport via E-470
# 3  1613069281_1533  113611087  Wagon Road PnR via Thornton Crossroads
# 4  1613069281_1538         -1                                     NaN
#
#   route_id                      route_long_name route_short_name route_type  \
# 0       AT     Arapahoe County / Denver Airport               AT        bus
# 1       AT     Arapahoe County / Denver Airport               AT        bus
# 2      AB1             Boulder / Denver Airport              AB1        bus
# 3     104L  Wagon Road / Denver Airport Limited             104L        bus
# 4      NaN                                  NaN              NaN        NaN
#
#                                    route_desc  vehicle_lat  vehicle_lng  \
# 0  This Route Travels Northbound & Southbound    39.657768  -104.846603
# 1  This Route Travels Northbound & Southbound    39.828133  -104.782166
# 2    This Route Travels Eastbound & Westbound    39.986767  -105.232735
# 3    This Route Travels Eastbound & Westbound    39.885300  -104.890984
# 4                                         NaN    40.016582  -105.249031
#
#    bearing         status                 timestamp  stop_id  \
# 0      202  in_transit_to 2021-02-11 11:47:37-07:00    19074
# 1       38  in_transit_to 2021-02-11 11:47:54-07:00    34651
# 2      121     stopped_at 2021-02-11 11:44:56-07:00    33855
# 3      270  in_transit_to 2021-02-11 11:47:09-07:00    13960
# 4        0  in_transit_to 2021-02-11 11:39:00-07:00       -1
#
#                                     stop_name                      stop_desc  \
#   (39.743342, -105.01276100000001),
#   (39.755421999999996, -105.00296999999999),
#   (39.643119, -104.87767),
#   (39.731664, -105.005549),
#   (39.679672, -104.93771399999999),
#   (39.746121, -104.99283799999999),
#   (39.561818, -104.87228200000001),
#   (39.720037, -105.12964),
#   (39.693283, -104.97868400000002),
#   (39.612258000000004, -105.014684),
#   (39.579865000000005, -105.02520200000001),
#   (39.736662, -105.06591),
#   (39.677331, -104.99294599999999),
#   (39.746121, -104.99283799999999),
#   (39.740285, -105.001608),
#   (39.726394, -105.200985),
#   (39.701958000000005, -104.990075),
#   (39.648971, -104.91643899999998),
#   (39.753528, -104.97949299999999),
#   (39.744907, -104.992421)])

# %%
rtd_df = pd.read_csv('/Users/joesanfilippo/Documents/dsi/repos/capstone_1/data/rtd_data_capture.csv')
rtd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98078 entries, 0 to 98077
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   entity_id                 98077 non-null  object
#  1   trip_id                   98077 non-null  float64
#  2   trip_headsign             77471 non-null  object
#  3   route_id                  77471 non-null  object
#  4   route_long_name           77471 non-null  object
#  5   route_short_name          77471 non-null  object
#  6   route_type                77471 non-null  object
#  7   route_desc                77471 non-null  object
#  8   vehicle_lat               98077 non-null  float64
#  9   vehicle_lng               98077 non-null  float64
#  10  bearing                   98077 non-null  float64
#  11  status                    98077 non-null  object
#  12  timestamp                 98077 non-null  object
#  13  stop_id                   98077 non-null  float64
#  14  stop_name                 76494 non-null  object
#  15  stop_desc                 76494 non-null  object
#  16  stop_lat                  76494 non-null  float64
#  17  stop_lon                  76494 non-null  float64
#  18  scheduled_arrival_time    75121 non-null  object
#  19  scheduled_departure_time  75121 non-null  object
#  20  vehicle_id                98077 non-null  object
#  21  vehicle_label             98077 non-null  float64
# dtypes: float64(8), object(14)
# memory usage: 16.5+ MB

# %%
rtd_df['distance_to_stop'] = calculate_distance(rtd_df.vehicle_lat, rtd_df.vehicle_lng, rtd_df.stop_lat, rtd_df.stop_lon)

# %%
# rtd_df.scheduled_departure_time.apply(lambda x: print(type(x)))
set([int(x[0:2]) if type(x)==str else x for x in rtd_df.scheduled_departure_time])
# Out:
# {nan, 4, 5, 6, 7, 8, 9, 10, 11, 24}

# %%
for __ in range(len(rtd_df.scheduled_departure_time)):
    print(f'{rtd_df.scheduled_departure_time[__]}: ')
    print(f'{pd.Timestamp(rtd_df.scheduled_departure_time[__])}')
# Out:
# nan:
# NaT
# nan:
# NaT
# nan:
# NaT
# nan:
# NaT
# nan:
# NaT
# nan:
# NaT
# nan:
# NaT
# nan:
# NaT
# nan:
# NaT
# nan:
# NaT
# nan:
# NaT
# nan:
# NaT
# nan:
# NaT
# nan:
# NaT
# nan:
# NaT
# nan:
# NaT
# nan:
# NaT
# nan:
# NaT
# nan:
# NaT
# nan:
# NaT
# nan:
# NaT
# nan:
# NaT
# nan:
# NaT
# nan:
# NaT
# nan:
# NaT
# nan:
# NaT
# nan:
# NaT
# 24:01:40:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     654         try:
# --> 655             ret = self._build_naive(res, default)
#     656         except ValueError as e:
#
# /opt/anaconda3/lib/python3.7/site-packages/dateutil/parser/_parser.py in _build_naive(self, res, default)
#    1240
# -> 1241         naive = default.replace(**repl)
#    1242
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.convert_str_to_tsobject()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# /opt/anaconda3/lib/python3.7/site-packages/dateutil/parser/_parser.py in parse(timestr, parserinfo, **kwargs)
#    1373     else:
# -> 1374         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1375
#
# /opt/anaconda3/lib/python3.7/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     656         except ValueError as e:
# --> 657             six.raise_from(ParserError(e.args[0] + ": %s", timestr), e)
#     658
#
# /opt/anaconda3/lib/python3.7/site-packages/six.py in raise_from(value, from_value)
#
# ParserError: hour must be in 0..23: 24:01:40
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-dc9503c67288> in <module>
#       1 for __ in range(len(rtd_df.scheduled_departure_time)):
#       2     print(f'{rtd_df.scheduled_departure_time[__]}: ')
# ----> 3     print(f'{pd.Timestamp(rtd_df.scheduled_departure_time[__])}')
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.Timestamp.__new__()
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.convert_to_tsobject()
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.convert_str_to_tsobject()
#
# ValueError: could not convert string to Timestamp

# %%
rtd_df['time_to_departure'] = calculate_time(pd.to_datetime(rtd_df.timestamp), rtd_df.scheduled_departure_time)
